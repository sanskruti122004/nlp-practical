# %%
pip install gensim nltk pandas
# Out:
# Requirement already satisfied: gensim in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.4.0)
# Requirement already satisfied: nltk in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.9.2)
# Requirement already satisfied: pandas in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.18.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gensim) (2.2.1)
# Requirement already satisfied: scipy>=1.7.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gensim) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: click in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.3)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 1: Load Dataset
import json

data = []
with open("Cell_Phones_and_Accessories_5.json", "r", encoding="utf-8") as f:
    for line in f:
        data.append(json.loads(line))

print("Dataset size:", len(data))
# Out:
# Dataset size: 194439

# %%
# Step 3: Preprocessing
import nltk, re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def preprocess(text):
    text = re.sub(r'[^a-z\s]', '', text.lower())
    words = word_tokenize(text)
    return [w for w in words if w not in stop_words]

tokenized_sentences = [preprocess(s) for s in sentences if s]
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Sakshi
# [nltk_data]     Jadhav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Sakshi
# [nltk_data]     Jadhav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Step 4: Train Word2Vec
from gensim.models import Word2Vec

w2v_model = Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100,
    window=5,
    min_count=5
)

# %%
# Similar words
print("\nWord2Vec Similar Words:")
print(w2v_model.wv.most_similar("phone"))
# Out:
# Word2Vec Similar Words:
# [('phones', 0.5903828740119934), ('iphone', 0.5728216171264648), ('phonethe', 0.5257765054702759), ('phonei', 0.5088217258453369), ('cellphone', 0.49971696734428406), ('phoneit', 0.48147526383399963), ('device', 0.4552292227745056), ('smartphone', 0.44260576367378235), ('case', 0.42885279655456543), ('face', 0.4202079474925995)]

# %%
# Similarity
print("Similarity (phone, mobile):",
      w2v_model.wv.similarity("phone", "mobile"))
# Out:
# Similarity (phone, mobile): -0.019010719

# %%
# Step 5: Train FastText
from gensim.models import FastText

ft_model = FastText(
    sentences=tokenized_sentences,
    vector_size=100,
    window=5,
    min_count=5
)

print("\nFastText Similar Words:")
print(ft_model.wv.most_similar("phone"))

print("Similarity (phone, mobile):",
      ft_model.wv.similarity("phone", "mobile"))
# Out:
# FastText Similar Words:
# [('phonelynx', 0.9316835999488831), ('phoneoh', 0.9310241341590881), ('phoneno', 0.9307284355163574), ('phoneis', 0.9302386045455933), ('phonea', 0.9283444285392761), ('phoneor', 0.9244833588600159), ('phonenot', 0.9204263687133789), ('phonehe', 0.9163386225700378), ('phoneto', 0.9156189560890198), ('phoneps', 0.9131149053573608)]
# Similarity (phone, mobile): 0.14686783
